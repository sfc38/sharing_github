# %% [markdown]
# Sevket Fatih Catpinar <br>
# fatihcatpinar@gmail.com <br>
# 5/5/2020
#
# __Project Proposal__
#
# The Data Source: https://www.kaggle.com/c/zillow-prize-1/data <br>
# Size of data: 340 MB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_properties_2016 = pd.read_csv("data/zillow-prize-1/properties_2016.csv")
df_properties_2016.shape
# Out:
# (2985217, 58)

# %%
df_properties_2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# ...

# %%
df_train_2016_v2 = pd.read_csv("data/zillow-prize-1/train_2016_v2.csv")
df_train_2016_v2.shape
# Out:
# (90275, 3)

# %%
df_train_2016_v2.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
# merge files to combine the properties and the log error
df = pd.merge(df_train_2016_v2, df_properties_2016, on='parcelid', how='left')
df.shape
# Out:
# (90275, 60)

# %%
df.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    1.0
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    1.0
# 3  12643413    0.0218      2016-01-02                    1.0
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          3.0         2.0
# 3                       NaN           NaN          2.0         2.0
# 4                       NaN           NaN          2.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid  ...  numberofstories  \
# 0                  NaN                    4.0  ...              NaN
# ...

# %%
df.describe()

# count does not include NaNs
# Out:
#            parcelid      logerror  airconditioningtypeid  \
# count  9.027500e+04  90275.000000           28781.000000
# mean   1.298466e+07      0.011457               1.816372
# std    2.504510e+06      0.161079               2.974168
# min    1.071174e+07     -4.605000               1.000000
# 25%    1.155950e+07     -0.025300               1.000000
# 50%    1.254734e+07      0.006000               1.000000
# 75%    1.422755e+07      0.039200               1.000000
# max    1.629608e+08      4.737000              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                261.000000     43.000000  90275.000000  90275.000000
# mean                   7.229885    713.581395      2.279474      3.031869
# std                    2.716196    437.434198      1.004271      1.156436
# min                    2.000000    100.000000      0.000000      0.000000
# 25%                    7.000000    407.500000      2.000000      2.000000
# ...

# %%
# ignore features that is less than 100

# df = df[df.count().keys()[df.count()>100]].count()

# %%
# number of transactions in each month

df['transaction_month'] = pd.to_datetime(df['transactiondate']).dt.month
counts = df['transaction_month'].value_counts()

plt.figure()
sns.barplot(counts.index, counts.values)
plt.xticks(rotation='vertical')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
corrmat = df.corr(method='spearman')
f, ax = plt.subplots(figsize=(8, 8))

# Draw the heatmap using seaborn
sns.heatmap(corrmat, vmax=1., square=True)
plt.title("Important variables correlation map", fontsize=15)
plt.show()
